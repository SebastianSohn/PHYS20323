# %% [markdown]
# # PyObject:  Object-oriented programming HW

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np
# your solution here
class Particle(object):
    def __init__(self, x, y, z, m, vx, vy, vz):
        self.x = x
        self.y = y
        self.z = z
        self.m = m
        self.vx = vx
        self.vy = vy
        self.vz = vz
    def kinetic_energy(self):
        print(0.5*self.m*((self.vx+self.vy+self.vz)**2))
    def find_separation(self, other):
        print(np.sqrt((self.x - other.x)**2 + (self.y - other.y)**2 + (self.z - p2.z)**2))
    def update_position(self,dt):
        print(dt*(self.x + self.y + self.z))

class ChargedParticle(Particle):
    def __init__(self, x, y, z, m, vx, vy, vz, charge):
        self.x = x
        self.y = y
        self.z = z
        self.m = m
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge
        
p1 = ChargedParticle(1,1,1,1,1,1,1,5)
p2 = Particle(2,2,2,2,2,2,2)
p1.kinetic_energy()
p1.find_separation(p2)
p1.update_position(2)
p1.charge
# Out:
# 4.5
# 1.7320508075688772
# 6
# 5

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (*not correct physics*) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.25 time steps for 100 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-2,-2,-2) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.25 time steps for 100 steps, and print the current poition and velocity of each particle at each time step.

# %%
# write new code here
# your solution here
class Particle(object):
    def __init__(self, x, y, z, m, vx, vy, vz):
        self.x = x
        self.y = y
        self.z = z
        self.m = m
        self.vx = vx
        self.vy = vy
        self.vz = vz
    def kinetic_energy(self):
        print(0.5*self.m*((self.vx+self.vy+self.vz)**2))
   
    def find_separation(self, other):
        print(np.sqrt((self.x - other.x)**2 + (self.y - other.y)**2 + (self.z - p2.z)**2))
        
    def update_position(self,dt):
        self.x = self.x + self.vx*dt
        self.y = self.y + self.vy*dt
        self.z = self.z + self.vz*dt

        
class ChargedParticle(Particle):
    def __init__(self, x, y, z, mass, vx, vy, vz, charge):
        self.x = x
        self.y = y
        self.z = z
        self.mass = mass
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge
    
    def find_separation(self, other):
        print(np.sqrt((self.x - other.x)**2 + (self.y - other.y)**2 + (self.z - other.z)**2))
    
    def interaction(self, other): 
        if np.sqrt((self.x - other.x)**2 + (self.y - other.y)**2 + (self.z - other.z)**2) < 0.25:
            print("interaction")
            if (self.charge > 0 and other.charge < 0) or (self.charge < 0 and other.charge > 0):
                self.vx = 0 
                self.vy = 0 
                self.vz = 0  
                other.vx = 0 
                other.vy = 0 
                other.vz = 0
                print("merge")
            else:
                print("repel")
                self.vx = self.vx*(-1*(self.charge+other.charge)*(self.mass/other.mass)) 
                self.vy = self.vy*(-1*(self.charge+other.charge)*(self.mass/other.mass)) 
                self.vz = self.vz*(-1*(self.charge+other.charge)*(self.mass/other.mass))
                other.vx = other.vx*(-1*(self.charge+other.charge)*(other.mass/self.mass)) 
                other.vy = other.vy*(-1*(self.charge+other.charge)*(other.mass/self.mass)) 
                other.vz = other.vz*(-1*(self.charge+other.charge)*(other.mass/self.mass))
        
p1 = ChargedParticle(-5,-5,-5,7,2,2,2,0.5)
p2 = ChargedParticle(5,5,5,7,-2,-2,-2,2)

for dt in np.arange(0, 25, .25):
    p1.update_position(dt)
    p2.update_position(dt)
    p1.interaction(p2)
    p1.find_separation(p2)
# Out:
# 17.320508075688775
# 15.588457268119896
# 12.12435565298214
# 6.928203230275509
# interaction
# repel
# 0.0
# 21.650635094610966
# 47.63139720814412
# 77.94228634059948
# 112.58330249197702
# 151.55444566227678
# 194.8557158514987
# 242.4871130596428
# 294.44863728670913
# 350.74028853269766
# 411.36206679760835
# 476.31397208144125
# 545.5960043841964
# 619.2081637058736
# 697.1504500464731
# 779.4228634059948
# 866.0254037844386
# 956.9580711818047
# 1052.220865598093
# 1151.8137870333035
# 1255.736835487436
# 1363.990010960491
# 1476.5733134524678
# 1593.486742963367
# 1714.7302994931886
# 1840.303983041932
# 1970.207793609598
# 2104.441731196186
# 2243.005795801696
# 2385.8999874261285
# 2533.124306069483
# 2684.67875173176
# 2840.5633244129585
# 3000.77802411308
# 3165.322850832123
# 3334.197804570089
# 3507.4028853269765
# 3684.9380931027863
# 3866.8034278975188
# 4052.998889711173
# 4243.524478543749
# 4438.3801943952485
# 4637.566037265669
# 4841.082007155012
# 5048.928104063278
# 5261.104327990465
# 5477.610678936574
# 5698.447156901606
# 5923.61376188556
# 6153.110493888436
# 6386.937352910235
# 6625.094338950956
# 6867.581452010599
# 7114.398692089164
# 7365.54605918665
# 7621.02355330306
# 7880.831174438392
# 8144.968922592646
# 8413.436797765822
# 8686.23479995792
# 8963.36292916894
# 9244.821185398883
# 9530.609568647747
# 9820.728078915534
# 10115.176716202244
# 10413.955480507875
# 10717.064371832428
# 11024.503390175903
# 11336.272535538303
# 11652.371807919622
# 11972.801207319864
# 12297.560733739028
# 12626.650387177115
# 12960.070167634125
# 13297.820075110056
# 13639.900109604909
# 13986.310271118684
# 14337.050559651381
# 14692.120975203
# 15051.521517773544
# 15415.252187363008
# 15783.312983971395
# 16155.703907598703
# 16532.424958244934
# 16913.47613591009
# 17298.85744059416
# 17688.56887229716
# 18082.61043101908
# 18480.982116759922
# 18883.683929519684
# 19290.715869298372
# 19702.07793609598
# 20117.77012991251
# 20537.792450747962
# 20962.14489860234
# 21390.827473475634
